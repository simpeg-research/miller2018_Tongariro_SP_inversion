# %%
# -*- coding: utf-8 -*-
"""
Script to invert Tongariro SP data using divergence of streaming current density, q.

from Soegi Kang, Dominique Fournier, UBC, Craig Miller, GNS

https://github.com/simpeg

Please use the miller_tongariro_2018 branch.  32Gb ram are recommended to run the model.

"""
from simpeg import utils, maps, directives, data_misfit, regularization, optimization, inversion, inverse_problem, data
import simpeg.electromagnetics.static.utils as staticutils
import simpeg.electromagnetics.static as em_static
from simpeg.electromagnetics.static import self_potential as sp
from simpeg.utils import download

import discretize as Mesh
from pymatsolver import PardisoSolver

import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import numpy as np

import os

from sklearn.metrics import mean_squared_error as mse

#import colorcet as cc

import tarfile

tar_folder = download( "https://storage.googleapis.com/simpeg/miller_et_al_2018.tar.gz")  
tar = tarfile.open(tar_folder, "r:*")
tar.extractall()
tar.close()

datadir ="./miller_et_al_2018/"

plt.close('all')
# Out:
# file already exists, new file is called D:\Dropbox\GIT\miller2018_Tongariro_SP_inversion\notebooks\miller_et_al_2018.tar.gz
# Downloading https://storage.googleapis.com/simpeg/miller_et_al_2018.tar.gz
#    saved to: D:\Dropbox\GIT\miller2018_Tongariro_SP_inversion\notebooks\miller_et_al_2018.tar.gz
# Download completed!

# %%
# load files

topo = np.loadtxt(datadir+'topoxyz.dat', skiprows=1)
dataInv = np.loadtxt(datadir+'Tongariro_SP_data.dat')

cond_model_file = datadir+'MT_model_for_SP_inv.con'
mesh_file = datadir+'Tongariro_SP.msh'

# %%
topo = topo[(topo[:,0] < 1833000) & (topo[:,0] > 1824000)]
topo = topo[(topo[:,1] > 5662000) & (topo[:,1] < 5670000)]
topoInv = topo

# %%
#set up the mesh
mesh = Mesh.TensorMesh.read_UBC(mesh_file)

print( mesh)
print( 'width in X direction', mesh.h[0].sum(), 'm')
print( 'width in Y direction', mesh.h[1].sum(), 'm')
print( 'width in Z direction', mesh.h[2].sum(), 'm')
print( 'number of cells', mesh.nC)

xref, yref = 1830000, 5666000
# Out:
#   TensorMesh: 450,296 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     77  1,824,200.00  1,832,281.00    100.00    207.00    1.20
#    y     68  5,662,200.00  5,669,498.00    100.00    207.00    1.30
#    z     86       -850.13      2,355.00     20.00    344.65    1.30
#
#
# width in X direction 8081.0 m
# width in Y direction 7298.0 m
# width in Z direction 3205.133662 m
# number of cells 450296

# %%
#sigma is background conductivity (S/m)

#read in model file
resistivity = mesh.read_model_UBC(cond_model_file) #read background conductivity model from file
sigma = 1/resistivity #change to S/m from ohmm
active_cells = sigma != 1e-8
#sigma = np.ones(mesh.nC)*1e-3 # sets uniform background
sigma[~active_cells] = 1e-8 #sigma of cells above topo = 1e-8
air_conductivity = np.log(1e-8)

# %%
#set active cells
active_map = maps.InjectActiveCells(mesh, active_cells, np.exp(air_conductivity)) #makes cell below topo active and sets cells above topo to 0
mesh2D, topoCC = staticutils.gettopoCC(mesh, active_cells) #~active_cells = opposite of active_cells, ie swaps True for False

# %%
#drape points onto topo
xyzlocInv = staticutils.drapeTopotoLoc(mesh, dataInv[:,:2], actind=active_cells) #drape data onto topo.
#xyzlocInv = np.c_[xyzlocInv[:,:2], xyzlocInv[:,2]]

# %%
#  Inversion runs in the next sections.
# Setup the problem
ind = np.argmin(abs(xyzlocInv[:, 0]-xref)+abs(xyzlocInv[:, 1]-yref))
inds = np.ones(xyzlocInv.shape[0], dtype='bool')
inds[ind] = False
xyzM = xyzlocInv[inds, :]
xyzN = np.atleast_2d(xyzlocInv[ind]).repeat(xyzM.shape[0], axis=0)
#wires = maps.Wires(('jsx', active_map.nP), ('jsy', active_map.nP), ('jsz', active_map.nP))
#prob = sp.Problem_CC_Jstore(mesh, sigma=sigma, qMap=active_map, Solver=PardisoSolver)

rx = em_static.resistivity.receivers.Dipole(xyzM, xyzN, data_type='volt')
src = sp.sources.StreamingCurrents([rx], L=np.ones(mesh.nC), mesh=mesh, modelType="CurrentSource")
sp_survey = sp.Survey([src])
sp_survey.dobs = (dataInv[1:,2]-dataInv[0,2])  # mV

q_map = sp.CurrentDensityMap(mesh, active_cells)
simulation = sp.Simulation3DCellCentered(mesh, sigma=sigma, survey=sp_survey, qMap=q_map)
simulation.solver = PardisoSolver

plt.hist(sp_survey.dobs, bins=100)
plt.show()

# %%
dobs = (dataInv[1:,2] - dataInv[0,2])
sp_data = data.Data(survey=sp_survey, dobs=dobs)

sp_data.standard_deviation = 30 #survey std dev in mV
sp_data.noise_floor = 60 # survey noise floor in mV


dmisfit = data_misfit.L2DataMisfit(simulation=simulation, data=sp_data)

regmap = maps.IdentityMap(nP = active_map.nP*3)
reg = regularization.Sparse(mesh, mapping=regmap, active_cells=active_cells)

reg.alpha_s = 1

reg.norms = [0, 1, 1, 1]

opt = optimization.ProjectedGNCG(maxIter=100, maxIterCG=10, tolX=1e-20, tolF=1e-20)

opt.maxIterLS = 20

sp_inverse_problem = inverse_problem.BaseInvProblem(dmisfit, reg, opt)

target = directives.TargetMisfit()

# Create an inversion object
update_Jacobi = directives.UpdatePreconditioner()
update_SensWeight = directives.UpdateSensitivityWeights()

IRLS = directives.Update_IRLS(
        f_min_change=1e-3, minGNiter=2, max_irls_iterations = 10,
        coolingFactor=8, coolingRate=3
        )


betaest = directives.BetaEstimate_ByEig(beta0_ratio=1.)
updateprecond = directives.UpdatePreconditioner()

#LP only
inv = inversion.BaseInversion(sp_inverse_problem, directiveList=[IRLS, update_SensWeight, updateprecond, betaest])

#save iterations
simulation.counter = opt.counter = utils.Counter()
opt.LSshorten = 0.5
opt.remember('xc')

#creates an initial starting model m0
m0 = np.ones(active_map.nP*3)*0.001
reg.reference_model = m0

# %%
#run the inversion
mopt_Lp = inv.run(m0)
Lp_amp = active_map*mopt_Lp

#recall a particular iteration, comment out if not needed.
xc = opt.recall('xc')
mopt_Lp = xc[8]
Lp_amp = active_map*mopt_Lp
# Out:
# Running inversion with SimPEG v0.22.1
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DCellCentered problem***
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 #run the inversion
# ----> 2 mopt_Lp = inv.run(m0)
#       3 Lp_amp = active_map*mopt_Lp
#       5 #recall a particular iteration, comment out if not needed.
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\utils\counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\inversion.py:110, in BaseInversion.run(self, m0)
#     103 @timeIt
#     104 def run(self, m0):
#     105     """run(m0)
#     106
#     107     Runs the inversion!
#     108
#     109     """
# --> 110     self.invProb.startup(m0)
#     111     self.directiveList.call("initialize")
#     112     print("model has any nan: {:b}".format(np.any(np.isnan(self.invProb.model))))
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\utils\code_utils.py:357, in call_hooks.<locals>.callHooksWrap.<locals>.wrapper(self, *args, **kwargs)
#     354             print((match + " is calling self." + method))
#     355         getattr(self, method)(*args, **kwargs)
# --> 357     return f(self, *args, **kwargs)
#     358 else:
#     359     out = f(self, *args, **kwargs)
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\inverse_problem.py:237, in BaseInvProblem.startup(self, m0)
#     233     solver = DefaultSolver
#     234     solver_opts = {}
#     236 self.opt.bfgsH0 = solver(
# --> 237     sp.csr_matrix(self.reg.deriv2(self.model)), **solver_opts
#     238 )
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\objective_function.py:489, in ComboObjectiveFunction.deriv2(self, m, v, f)
#     487         objfct_H = objfct.deriv2(m, v, f=f[i])
#     488     else:
# --> 489         objfct_H = objfct.deriv2(m, v)
#     490     H = H + multiplier * objfct_H
#     491 return H
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\utils\counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\simpeg\regularization\base.py:519, in BaseRegularization.deriv2(self, m, v)
#     517 f_m_deriv = self.f_m_deriv(m)
#     518 if v is None:
# --> 519     return 2 * f_m_deriv.T * ((self.W.T * self.W) * f_m_deriv)
#     521 return 2 * f_m_deriv.T * (self.W.T * (self.W * (f_m_deriv * v)))
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\scipy\sparse\_matrix.py:44, in spmatrix.__mul__(self, other)
#      43 def __mul__(self, other):
# ---> 44     return self._matmul_dispatch(other)
#
# File ~\AppData\Local\miniforge3\envs\simpeg\Lib\site-packages\scipy\sparse\_base.py:579, in _spbase._matmul_dispatch(self, other)
#     577 if issparse(other):
#     578     if self.shape[-1] != other.shape[0]:
# --> 579         raise ValueError('dimension mismatch')
#     580     return self._matmul_sparse(other)
#     582 # If it's a list or whatever, treat it like an array
#
# ValueError: dimension mismatch

# %%
#save models and calc data

mesh.write_model_UBC('Tongairo_C_Lp_amp.mod', Lp_amp)

#Write calculated data (Lp model)
Lp_calculated = survey.dpred(mopt_Lp)
np.savetxt('Lp_calculated_data.dat', Lp_calculated, fmt='%.4f')


RMS = np.sqrt(mse(Lp_calculated, survey.dobs))
print('RMS = %.3f mV' %RMS)

# %%
# Plot some L2 model obs and calc
plt.figure()
plt.plot(survey.dobs, '.', label = 'obs')
plt.plot(invProb.dpred, label = 'calc')
plt.legend()
plt.ylabel('mV')
plt.xlabel('data point index')
plt.annotate('B', xy=(0, 1000), fontsize=14)
plt.title('$q$ observed vs calculated.  RMS = %.0f mV' %RMS)
plt.show()

plt.figure()
plt.hist(mopt_Lp, bins=100, label='Lp model')
plt.legend()
plt.show()

# %%
# extract core mesh
temp = Lp_amp.copy()
temp[~active_cells] = np.nan
vmin, vmax = temp[active_cells].min(), temp[active_cells].max()

xmin, xmax = dataInv[:,0].min(), dataInv[:,0].max()
ymin, ymax = dataInv[:,1].min(), dataInv[:,1].max()
zmin, zmax = 700, topo[:,2].max()
xyzlim = np.array([[xmin, xmax], [ymin, ymax], [zmin, zmax]])
ind_core, mesh_core = Utils.ExtractCoreMesh(xyzlim, mesh)

ja_est_core = Utils.mkvc(temp[ind_core])
active_cells_core = active_cells[ind_core]
jamp_min, jamp_max = ja_est_core[:mesh_core.nC][active_cells_core].min(), ja_est_core[:mesh_core.nC][active_cells_core].max()
jamp_lp_core = temp[ind_core]
jamp_lp_core[~active_cells_core] = np.nan

# %%
# plot map views
fig, ((ax0,ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize = (10, 10))

fig.subplots_adjust(wspace=0, hspace=0)
axs = [ax0, ax1, ax2, ax3]
layers = [1500, 1200, 1000, 800]


clim=(-0.00005, 0.00005)
for i_layer, ax in enumerate(axs):   
    jamp_lp_core[~active_cells_core] = np.nan
    indz = int(np.argmin(abs(mesh_core.vectorCCz-layers[i_layer])))
    cbar = mesh_core.plotSlice(jamp_lp_core, ind=indz, normal='Z', clim=clim, ax=ax)
    
    minorLocator = AutoMinorLocator(4)
    ax.xaxis.set_minor_locator(minorLocator)
    ax.yaxis.set_minor_locator(minorLocator)

    ax.tick_params(which='both', width=2, direction='in')
    ax.tick_params(which='major', length=10, direction='in', top= True, right=True)
    ax.tick_params(which='minor', length=7, direction='in', top = True)
    
    ax.set_title('')
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_aspect('equal')
    ax.set_ylim(5663000, 5669000)
    ax.set_xlim(1825094, 1831794)    
    ax.set_title(("%.0f")%(layers[i_layer]))
    ax.set_xticks(np.arange(1826000, 1832000, 2000))
    ax.set_yticks(np.arange(5663000, 5670000, 2000))
    
    if ~np.logical_or(i_layer==2,i_layer==3):
        ax.set_xticklabels([])
    if np.logical_or(i_layer==1,i_layer==3):
        ax.set_yticklabels({})

plt.tight_layout()
plt.show()

# %%
# plot section views
fig, ((ax0,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(nrows=3, ncols=2, figsize = (10, 10))

fig.delaxes(ax5)

fig.subplots_adjust(wspace=0, hspace=0)
axs = [ax0, ax1, ax2, ax3, ax4, ax5]
layers = [5667994, 5666994, 5665994, 5664994, 5663994]

stream_color = 'k'
clim = (-0.00005, 0.00005)
for i_layer, ax in enumerate(axs[:-1]):
    jamp_lp_core[~active_cells_core] = np.nan
    indy = int(np.argmin(abs(mesh_core.vectorCCy-layers[i_layer])))
    cbar = mesh_core.plotSlice(jamp_lp_core, ind=indy, normal='Y', clim=clim, ax=ax)

    minorLocator = AutoMinorLocator(4)
    ax.xaxis.set_minor_locator(minorLocator)
    ax.yaxis.set_minor_locator(minorLocator)

    ax.tick_params(which='both', width=2, direction='in')
    ax.tick_params(which='major', length=10, direction='in', top= True, right=True)
    ax.tick_params(which='minor', length=7, direction='in', top = True)
    
    ax.set_title('')
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_aspect('equal')
    ax.set_ylim(700, 2000)
    ax.set_xlim(1825094, 1831794)    
    ax.set_title(("%.0f")%(layers[i_layer]))
    ax.set_xticks([1826000, 1828000, 1830000])
    ax.set_yticks([1000, 1500, 2000])
      
    if ~np.logical_or(i_layer==4,i_layer==3) :
        ax.set_xticklabels([])
    if np.logical_or(i_layer==1,i_layer==3):
        ax.set_yticklabels({})

plt.tight_layout()
plt.show()

# %%
# Write core of the L2 model to file in spherical formulation
mesh_core.write_UBC('mesh_core.msh')

jamp_lp_core[~active_cells_core] = -100
mesh_core.write_model_UBC('Tongairo_C_Lp_amp_core.mod', jamp_lp_core)
